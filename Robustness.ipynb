# %% [markdown]
# # Robustness checks

# %% [markdown]
# This notebook contains various robustness checks for the simulation results concerning the diversity-expertise trade-off in the evidential sources model. In particular, robustness checks for:
# 1. Team size.
# 2. Heuristic sizes: both different homogeneous heuristic sizes and heterogeneous heuristic sizes.
# 3. Number of sources.
# 4. Reliability distributions: different reliability distribution ranges.
#
# The notebook contains one section for each of these cases. Each section consists of three subsections:
# - Simulations, containing the code used to run the simulations;
# - Statistics tables containinig the results of one-sample Wilcoxon tests (including p-values, confidence intervals, effect sizes, and ratios); and
# - Heatmaps displaying the results for the three deliberative mechanisms.
#
# The required packages and modules are imported in the *Setup* section.
#
# ---

# %% [markdown]
# ## Setup
# ---

# %%
import os
import pprint
from math import comb

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from IPython.display import display

from data_analysis.statistics import produce_df_1samp
from figures.generate_heatmap import heatmap
from grid_simulation import GridSimulation
from models.generate_teams import generate_diverse_team, generate_expert_team
from models.sources import Sources

translate_outcome_mechanism: dict = {
    "accuracy_opinion": "opinion-based mechanism",
    "accuracy_evidence": "evidence-based mechanism",
    "accuracy_bounded": "boundedly-rational evidence-based mechanism"
}

# %% [markdown]
# ## Team size
# ---

# %% [markdown]
# We are varying the size of the teams to include not only `9` but also `5`, and `7`.

# %% [markdown]
# ### Simulations

# %%
team_size = 5

GridSimulation(
    team_types=["expert", "diverse"],
    n_sources_list=[13, 17],
    reliability_distribution_list=rels,
    team_size=team_size,
    n_samples=10**3,
    estimate_sample_size=10**3,
).run()
# Out:
#           team_types  n_sources reliability_distribution  heuristic_size  \
# 0  [expert, diverse]         13        (equi, 0.55, 0.2)               5
# 1  [expert, diverse]         13         (equi, 0.6, 0.2)               5
# 2  [expert, diverse]         13        (equi, 0.65, 0.2)               5
# 3  [expert, diverse]         13         (equi, 0.7, 0.2)               5
# 4  [expert, diverse]         13        (equi, 0.75, 0.2)               5
#
#    team_size  n_samples estimate_sample_size
# 0          5       1000                 None
# 1          5       1000                 None
# 2          5       1000                 None
# 3          5       1000                 None
# 4          5       1000                 None
# Running simulation 0
# 100%|██████████| 1001/1001 [04:17<00:00,  3.89it/s]
# Running simulation 1
# 100%|██████████| 1001/1001 [04:21<00:00,  3.82it/s]
# Running simulation 2
# 100%|██████████| 1001/1001 [04:18<00:00,  3.88it/s]
# Running simulation 3
# 100%|██████████| 1001/1001 [04:16<00:00,  3.90it/s]
# Running simulation 4
# 100%|██████████| 1001/1001 [04:18<00:00,  3.87it/s]

# %%
team_size = 7

GridSimulation(
    team_types=["expert", "diverse"],
    n_sources_list=[13, 17],
    reliability_distribution_list=rels,
    team_size=team_size,
    n_samples=10**3,
    estimate_sample_size=10**3,
).run()
# Out:
#           team_types  n_sources reliability_distribution  heuristic_size  \
# 0  [expert, diverse]         13        (equi, 0.55, 0.2)               5
# 1  [expert, diverse]         13         (equi, 0.6, 0.2)               5
# 2  [expert, diverse]         13        (equi, 0.65, 0.2)               5
# 3  [expert, diverse]         13         (equi, 0.7, 0.2)               5
# 4  [expert, diverse]         13        (equi, 0.75, 0.2)               5
#
#    team_size  n_samples estimate_sample_size
# 0          7       1000                 None
# 1          7       1000                 None
# 2          7       1000                 None
# 3          7       1000                 None
# 4          7       1000                 None
# Running simulation 0
# 100%|██████████| 1001/1001 [04:47<00:00,  3.48it/s]
# Running simulation 1
# 100%|██████████| 1001/1001 [04:30<00:00,  3.70it/s]
# Running simulation 2
# 100%|██████████| 1001/1001 [04:35<00:00,  3.63it/s]
# Running simulation 3
# 100%|██████████| 1001/1001 [04:44<00:00,  3.52it/s]
# Running simulation 4
# 100%|██████████| 1001/1001 [04:31<00:00,  3.68it/s]

# %% [markdown]
# ### Simulation statistics tables

# %%
for outcome in ["accuracy_opinion", "accuracy_evidence", "accuracy_bounded"]:
    print("="*80)
    print(f"{translate_outcome_mechanism[outcome].capitalize()}")
    print("="*80)
    for team_size in [5, 7]:
        df_dummy = produce_df_1samp(outcome=outcome, team_size=team_size)
        print(f"--- Team size: {team_size}")
        display(df_dummy)
# Out:
# ================================================================================
# Opinion-based mechanism
# ================================================================================
# --- Team size: 5
#    n_sources  rel_mean  difference  error_reduction  p_value  effect_size  \
# 0         13      0.55      -0.083            -29.5      0.0        0.866
# 1         13      0.60      -0.046            -23.4      0.0        0.866
# 2         13      0.65      -0.019            -15.2      0.0        0.866
# 3         13      0.70      -0.003             -4.2      0.0        0.756
# 4         13      0.75       0.003              7.9      0.0        0.775
# 5         17      0.55      -0.094            -35.6      0.0        0.866
# 6         17      0.60      -0.049            -27.2      0.0        0.866
# 7         17      0.65      -0.018            -15.8      0.0        0.857
# 8         17      0.70      -0.001             -2.2      0.0        0.179
# 9         17      0.75       0.004             13.2      0.0        0.646
#
#      ci_low   ci_high   ties  ratio
# 0 -0.084177 -0.082574  False  1.000
# 1 -0.046664 -0.045611  False  1.000
# 2 -0.019613 -0.018753  False  1.000
# 3 -0.003435 -0.002672  False  0.846
# 4  0.002392  0.002736  False  0.872
# 5 -0.094913 -0.092812  False  1.000
# 6 -0.050549 -0.048381  False  1.000
# 7 -0.018910 -0.017428  False  0.960
# 8 -0.001989 -0.000803  False  0.571
# 9  0.003207  0.003823  False  0.797
# --- Team size: 7
#    n_sources  rel_mean  difference  error_reduction  p_value  effect_size  \
# 0         13      0.55      -0.083            -29.6      0.0        0.866
# 1         13      0.60      -0.046            -23.0      0.0        0.866
# 2         13      0.65      -0.017            -13.1      0.0        0.866
# 3         13      0.70      -0.001             -1.4      0.0        0.234
# 4         13      0.75       0.004             13.2      0.0        0.842
# 5         17      0.55      -0.084            -31.6      0.0        0.866
# 6         17      0.60      -0.033            -17.9      0.0        0.866
# 7         17      0.65       0.001              0.5      0.0        0.146
# 8         17      0.70       0.014             25.8      0.0        0.866
# 9         17      0.75       0.013             67.2      0.0        0.866
#
#      ci_low   ci_high   ties  ratio
# 0 -0.084168 -0.082766  False  1.000
# 1 -0.045890 -0.044843  False  1.000
# 2 -0.017170 -0.016287  False  1.000
# 3 -0.001460 -0.000781  False  0.588
# 4  0.003936  0.004421  False  0.946
# 5 -0.084210 -0.082936  False  1.000
# 6 -0.033334 -0.032301  False  1.000
# 7  0.000296  0.000942  False  0.553
# 8  0.013350  0.013767  False  1.000
# 9  0.012490  0.012670  False  1.000
# ================================================================================
# Evidence-based mechanism
# ================================================================================
# --- Team size: 5
#    n_sources  rel_mean  difference  error_reduction  p_value  effect_size  \
# 0         13      0.55      -0.050            -16.2      NaN          NaN
# 1         13      0.60      -0.014             -6.5      NaN          NaN
# 2         13      0.65       0.009              7.1      NaN          NaN
# 3         13      0.70       0.017             28.6      NaN          NaN
# 4         13      0.75       0.015             64.2      NaN          NaN
# 5         17      0.55      -0.059            -21.2      NaN          NaN
# 6         17      0.60      -0.008             -4.1      NaN          NaN
# 7         17      0.65       0.020             20.7      NaN          NaN
# 8         17      0.70       0.026             66.3      NaN          NaN
# 9         17      0.75       0.018            155.5      NaN          NaN
#
#    ci_low  ci_high   ties  ratio
# 0     NaN      NaN  False    NaN
# 1     NaN      NaN  False    NaN
# 2     NaN      NaN  False    NaN
# 3     NaN      NaN  False    NaN
# 4     NaN      NaN  False    NaN
# 5     NaN      NaN  False    NaN
# 6     NaN      NaN  False    NaN
# 7     NaN      NaN  False    NaN
# 8     NaN      NaN  False    NaN
# 9     NaN      NaN  False    NaN
# --- Team size: 7
#    n_sources  rel_mean  difference  error_reduction  p_value  effect_size  \
# 0         13      0.55      -0.050            -16.2      NaN          NaN
# 1         13      0.60      -0.014             -6.5      NaN          NaN
# 2         13      0.65       0.009              7.1      NaN          NaN
# 3         13      0.70       0.017             28.6      NaN          NaN
# 4         13      0.75       0.015             64.2      NaN          NaN
# 5         17      0.55      -0.059            -21.2      NaN          NaN
# 6         17      0.60      -0.008             -4.1      NaN          NaN
# 7         17      0.65       0.020             20.7      NaN          NaN
# 8         17      0.70       0.026             66.3      NaN          NaN
# 9         17      0.75       0.018            155.5      NaN          NaN
#
#    ci_low  ci_high   ties  ratio
# 0     NaN      NaN  False    NaN
# 1     NaN      NaN  False    NaN
# 2     NaN      NaN  False    NaN
# 3     NaN      NaN  False    NaN
# 4     NaN      NaN  False    NaN
# 5     NaN      NaN  False    NaN
# 6     NaN      NaN  False    NaN
# 7     NaN      NaN  False    NaN
# 8     NaN      NaN  False    NaN
# 9     NaN      NaN  False    NaN
# ================================================================================
# Boundedly-rational evidence-based mechanism
# ================================================================================
# --- Team size: 5
#    n_sources  rel_mean  difference  error_reduction  p_value  effect_size  \
# 0         13      0.55      -0.073            -25.9      0.0        0.866
# 1         13      0.60      -0.030            -15.2      0.0        0.866
# 2         13      0.65      -0.001             -0.6      0.0        0.866
# 3         13      0.70       0.012             19.8      0.0        0.866
# 4         13      0.75       0.012             53.0      0.0        0.866
# 5         17      0.55      -0.081            -30.8      0.0        0.866
# 6         17      0.60      -0.029            -16.1      0.0        0.866
# 7         17      0.65       0.003              2.8      0.0        0.309
# 8         17      0.70       0.015             30.8      0.0        0.866
# 9         17      0.75       0.013             79.0      0.0        0.866
#
#      ci_low   ci_high   ties  ratio
# 0 -0.073133 -0.073133  False  1.000
# 1 -0.029876 -0.029876  False  1.000
# 2 -0.000778 -0.000778  False  1.000
# 3  0.011981  0.011981  False  1.000
# 4  0.012149  0.012149  False  1.000
# 5 -0.082932 -0.080042  False  1.000
# 6 -0.030605 -0.028221  False  0.991
# 7  0.002376  0.003688  False  0.622
# 8  0.014715  0.015626  False  0.996
# 9  0.013116  0.013502  False  1.000
# --- Team size: 7
#    n_sources  rel_mean  difference  error_reduction  p_value  effect_size  \
# 0         13      0.55      -0.076            -26.8      0.0        0.866
# 1         13      0.60      -0.032            -16.4      0.0        0.866
# 2         13      0.65      -0.003             -2.3      0.0        0.670
# 3         13      0.70       0.011             16.8      0.0        0.866
# 4         13      0.75       0.012             47.2      0.0        0.866
# 5         17      0.55      -0.071            -27.0      0.0        0.866
# 6         17      0.60      -0.013             -7.3      0.0        0.866
# 7         17      0.65       0.019             19.8      0.0        0.866
# 8         17      0.70       0.027             70.0      0.0        0.866
# 9         17      0.75       0.020            170.7      0.0        0.866
#
#      ci_low   ci_high   ties  ratio
# 0 -0.076343 -0.075493  False  1.000
# 1 -0.032991 -0.032337  False  1.000
# 2 -0.003005 -0.002768  False  0.802
# 3  0.010315  0.010767  False  1.000
# 4  0.011502  0.011692  False  1.000
# 5 -0.071399 -0.071399  False  1.000
# 6 -0.013419 -0.013419  False  1.000
# 7  0.019316  0.019316  False  1.000
# 8  0.027148  0.027148  False  1.000
# 9  0.019726  0.019726  False  1.000

# %% [markdown]
# ### Simulation overview results

# %%
def display_results_team_size(outcome: str = "accuracy_opinion", n_sources: int = 13):
    data = []
    for team_size in [3, 5, 7, 9]:
        df_dummy = produce_df_1samp(outcome=outcome, team_size=team_size, compute_ci=False)
        for idx, row in df_dummy.iterrows():
            data.append([
                row["n_sources"], 
                row["rel_mean"], 
                team_size, 
                row["difference"], 
                row["p_value"], 
                row["effect_size"],
            ])
    df_results = pd.DataFrame(data, columns=["n_sources", "rel_mean", "team_size", "difference", "p_value", "effect_size"])
    df_results["effect_percent"] = 100 * df_results["difference"]
    df_results = df_results[df_results["n_sources"] == n_sources]
    return df_results 

def heatmap_results_team_size(outcome: str = "accuracy_opinion", n_sources: int = 13, show_cbar: bool = True):
    df_results = display_results_team_size(outcome=outcome, n_sources=n_sources)

    heatmap_df = df_results.pivot(index="rel_mean", columns="team_size", values="effect_percent")
    heatmap_df.sort_index(inplace=True, ascending=False)
    
    sns.set_style("white")
    font_style = {"family": "Times New Roman", "size": 12}
    plt.rc("font", **font_style)
    plt.figure(figsize=(5, 3))
    
    heatmap_params = {
        "annot": True,
        "cmap": "coolwarm",
        "square": True,
        "cbar_kws": {"shrink": 0.4},
        "vmin": -10,
        "vmax": 10,
        "cbar": show_cbar,
    }

    
    annot_df = heatmap_df.copy().map(lambda x: f"{x:.1f}")
    effect_df = df_results.pivot(index="rel_mean", columns="team_size", values="effect_size")
    effect_low = (effect_df < 0.1)
    effect_mid = (effect_df >= 0.1) & (effect_df < 0.3)
    annot_df[effect_low] = annot_df[effect_low] + "'"
    annot_df[effect_mid] = annot_df[effect_mid] + "''"
    
    pvalue_df = df_results.pivot(index="rel_mean", columns="team_size", values="p_value")
    not_sig = (pvalue_df > 0.001)
    annot_df[not_sig] = ""
    
    heatmap_params["annot"] = annot_df
    heatmap_params["fmt"] = ""

    fig = sns.heatmap(
        heatmap_df,
        **heatmap_params,
    )

    fig.set_xlabel("Team size (#)")
    fig.set_ylabel("Reliability (mean)")
    plt.yticks(rotation=0)
    plt.savefig(
        f"figures/images/robustness/heatmap_teamsize_{outcome}_nsources{n_sources}.eps",
        bbox_inches="tight",
        dpi=800,
        format="eps",
    )
    plt.savefig(
        f"figures/images/robustness/heatmap_teamsize_{outcome}_nsources{n_sources}.png",
        bbox_inches="tight",
        dpi=800,
    )
    plt.show()
    plt.close()

# %%
for outcome in ["accuracy_opinion", "accuracy_evidence", "accuracy_bounded"]:
    print("="*40)
    print(f"{translate_outcome_mechanism[outcome].capitalize()}")
    print("="*40)
    for n_sources in [13, 17]:
        print(f"--- Number of sources: {n_sources}")
        show_cbar = True if outcome == "accuracy_bounded" else False
        heatmap_results_team_size(outcome=outcome, n_sources=n_sources, show_cbar=show_cbar)
# Out:
# ========================================
# Opinion-based mechanism
# ========================================
# --- Number of sources: 13
# --- Number of sources: 17
# ========================================
# Evidence-based mechanism
# ========================================
# --- Number of sources: 13
# --- Number of sources: 17
# ========================================
# Boundedly-rational evidence-based mechanism
# ========================================
# --- Number of sources: 13
# --- Number of sources: 17

# %% [markdown]
# ## Heuristic sizes
# ---

# %% [markdown]
# We considered different *homogeneous* heuristic sizes (where all agents have the same heuristic size) and *heterogeneous* heuristic sizes (where the agents can have different heuristic sizes).

# %% [markdown]
# ### Homogeneous case

# %% [markdown]
# We vary the heuristic sizes and the number of sources to not only include heuristic size `5` and number of sources `13` and `17` but also
# - heuristic size `7` and both `13` and `15` sources, and
# - heuristic size `9` and `15` sources
#
# The heuristic sizes and number of sources are chosen in such a way that the total number of possible heuristics is roughly between 1,200 and 7,000.

# %%
heuristic_size = 7
print("=" * 40)
print(f"Heuristic size: {heuristic_size}")
print("=" * 40)
data = []
for n_sources in [11, 13, 15, 17]: 
    n_possible_heuristics = comb(n_sources, heuristic_size)
    data.append((n_sources, n_possible_heuristics))
    df = pd.DataFrame(data, columns=["n_sources", "n_possible_heuristics"])
    df["n_possible_heuristics"] = df["n_possible_heuristics"].map('{:,}'.format)
display(df)

heuristic_size = 9
print("=" * 40)
print(f"Heuristic size: {heuristic_size}")
print("=" * 40)
data = []
for n_sources in [13, 15, 17]: 
    n_possible_heuristics = comb(n_sources, heuristic_size)
    data.append((n_sources, n_possible_heuristics))
    df = pd.DataFrame(data, columns=["n_sources", "n_possible_heuristics"])
    df["n_possible_heuristics"] = df["n_possible_heuristics"].map('{:,}'.format)
display(df)
# Out:
# ========================================
# Heuristic size: 7
# ========================================
#    n_sources n_possible_heuristics
# 0         11                   330
# 1         13                 1,716
# 2         15                 6,435
# 3         17                19,448
# ========================================
# Heuristic size: 9
# ========================================
#    n_sources n_possible_heuristics
# 0         13                   715
# 1         15                 5,005
# 2         17                24,310

# %% [markdown]
# #### Simulations

# %%
rels = [
    ("equi", rel_mean, 0.2)
    for rel_mean in [0.55, 0.60, 0.65, 0.7, 0.75]]

GridSimulation(
    team_types=["expert", "diverse"],
    n_sources_list=[13, 15],
    reliability_distribution_list=rels,
    heuristic_size=7,
    n_samples=10**3,
    estimate_sample_size=10**3,
).run()

# %%
n_sources_list = [15]
heuristic_size = 9

for n_sources in n_sources_list:
    n_possible_heuristics = comb(n_sources, heuristic_size)
    print(f"{n_sources=}, {heuristic_size=}, {n_possible_heuristics=:,}")
# Out:
# n_sources=15, heuristic_size=9, n_possible_heuristics=5,005

# %%
rels = [
    ("equi", rel_mean, 0.2)
    for rel_mean in [0.55, 0.60, 0.65, 0.7, 0.75]]

GridSimulation(
    team_types=["expert", "diverse"],
    n_sources_list=[15],
    reliability_distribution_list=rels,
    heuristic_size=9,
    n_samples=10**3,
    estimate_sample_size=10**3,
).run()

# %% [markdown]
# #### Simulation statistics tables

# %%
for outcome in ["accuracy_opinion", "accuracy_evidence", "accuracy_bounded"]:
    print("="*40)
    print(f"{translate_outcome_mechanism[outcome].capitalize()}")
    print("="*40)
    for heuristic_size in [7, 9]:
        print(f"--- Heuristic size: {heuristic_size}")
        display(produce_df_1samp(
            outcome=outcome, 
            heuristic_size=heuristic_size, 
            n_sources_list=[13, 15, 17],
            )
        )
# Out:
# ========================================
# Opinion-based mechanism
# ========================================
# --- Heuristic size: 7
#    n_sources  rel_mean  difference  error_reduction  p_value  effect_size  \
# 0         13      0.55      -0.073            -25.5      0.0        0.866
# 1         13      0.60      -0.043            -22.3      0.0        0.866
# 2         13      0.65      -0.019            -16.8      0.0        0.866
# 3         13      0.70      -0.006             -9.3      0.0        0.866
# 4         13      0.75      -0.000             -0.9      0.0        0.280
# 5         15      0.55      -0.081            -29.8      0.0        0.866
# 6         15      0.60      -0.042            -23.6      0.0        0.866
# 7         15      0.65      -0.015            -14.4      0.0        0.866
# 8         15      0.70      -0.001             -2.3      0.0        0.540
# 9         15      0.75       0.003             13.1      0.0        0.866
#
#      ci_low   ci_high   ties  ratio
# 0 -0.073191 -0.072681  False  1.000
# 1 -0.042842 -0.042382  False  1.000
# 2 -0.019618 -0.019192  False  1.000
# 3 -0.005808 -0.005515  False  1.000
# 4 -0.000321 -0.000190  False  0.622
# 5 -0.081072 -0.080363  False  1.000
# 6 -0.042465 -0.041715  False  1.000
# 7 -0.015511 -0.015006  False  1.000
# 8 -0.001433 -0.001103  False  0.720
# 9  0.002575  0.002702  False  0.992
# --- Heuristic size: 9
#    n_sources  rel_mean  difference  error_reduction  p_value  effect_size  \
# 0         15      0.55      -0.071            -25.5      0.0        0.866
# 1         15      0.60      -0.041            -23.4      0.0        0.866
# 2         15      0.65      -0.019            -19.0      0.0        0.866
# 3         15      0.70      -0.006            -12.8      0.0        0.866
# 4         15      0.75      -0.001             -5.4      0.0        0.781
#
#      ci_low   ci_high   ties  ratio
# 0 -0.071387 -0.070723  False  1.000
# 1 -0.041424 -0.040829  False  1.000
# 2 -0.019018 -0.018664  False  1.000
# 3 -0.006200 -0.005943  False  1.000
# 4 -0.001053 -0.000895  False  0.877
# ========================================
# Evidence-based mechanism
# ========================================
# --- Heuristic size: 7
#    n_sources  rel_mean  difference  error_reduction  p_value  effect_size  \
# 0         13      0.55      -0.031             -9.7      NaN          NaN
# 1         13      0.60      -0.017             -8.3      NaN          NaN
# 2         13      0.65      -0.007             -5.6      NaN          NaN
# 3         13      0.70      -0.001             -1.8      NaN          NaN
# 4         13      0.75       0.001              3.4      NaN          NaN
# 5         15      0.55      -0.050            -17.1      NaN          NaN
# 6         15      0.60      -0.025            -13.4      NaN          NaN
# 7         15      0.65      -0.007             -7.1      NaN          NaN
# 8         15      0.70       0.001              1.7      NaN          NaN
# 9         15      0.75       0.002             14.2      NaN          NaN
#
#    ci_low  ci_high   ties  ratio
# 0     NaN      NaN  False    NaN
# 1     NaN      NaN  False    NaN
# 2     NaN      NaN  False    NaN
# 3     NaN      NaN  False    NaN
# 4     NaN      NaN  False    NaN
# 5     NaN      NaN  False    NaN
# 6     NaN      NaN  False    NaN
# 7     NaN      NaN  False    NaN
# 8     NaN      NaN  False    NaN
# 9     NaN      NaN  False    NaN
# --- Heuristic size: 9
#    n_sources  rel_mean  difference  error_reduction  p_value  effect_size  \
# 0         15      0.55      -0.029             -9.1      NaN          NaN
# 1         15      0.60      -0.015             -7.9      NaN          NaN
# 2         15      0.65      -0.006             -5.4      NaN          NaN
# 3         15      0.70      -0.001             -1.7      NaN          NaN
# 4         15      0.75       0.001              3.4      NaN          NaN
#
#    ci_low  ci_high   ties  ratio
# 0     NaN      NaN  False    NaN
# 1     NaN      NaN  False    NaN
# 2     NaN      NaN  False    NaN
# 3     NaN      NaN  False    NaN
# 4     NaN      NaN  False    NaN
# ========================================
# Boundedly-rational evidence-based mechanism
# ========================================
# --- Heuristic size: 7
#    n_sources  rel_mean  difference  error_reduction  p_value  effect_size  \
# 0         13      0.55      -0.069            -24.3      0.0        0.866
# 1         13      0.60      -0.036            -18.8      0.0        0.866
# 2         13      0.65      -0.012            -10.3      0.0        0.866
# 3         13      0.70       0.001              0.9      0.0        0.866
# 4         13      0.75       0.004             15.9      0.0        0.866
# 5         15      0.55      -0.075            -27.8      0.0        0.866
# 6         15      0.60      -0.033            -18.5      0.0        0.866
# 7         15      0.65      -0.005             -4.9      0.0        0.866
# 8         15      0.70       0.006             13.4      0.0        0.866
# 9         15      0.75       0.007             42.6      0.0        0.866
#
#      ci_low   ci_high   ties  ratio
# 0 -0.069386 -0.069386  False    1.0
# 1 -0.035880 -0.035880  False    1.0
# 2 -0.011839 -0.011839  False    1.0
# 3  0.000538  0.000538  False    1.0
# 4  0.003652  0.003652  False    1.0
# 5 -0.075208 -0.075208  False    1.0
# 6 -0.032933 -0.032933  False    1.0
# 7 -0.005197 -0.005197  False    1.0
# 8  0.006455  0.006455  False    1.0
# 9  0.006918  0.006918  False    1.0
# --- Heuristic size: 9
#    n_sources  rel_mean  difference  error_reduction  p_value  effect_size  \
# 0         15      0.55      -0.068            -24.4      0.0        0.866
# 1         15      0.60      -0.035            -19.8      0.0        0.866
# 2         15      0.65      -0.012            -12.2      0.0        0.866
# 3         15      0.70      -0.001             -1.7      0.0        0.866
# 4         15      0.75       0.002             11.9      0.0        0.866
#
#      ci_low   ci_high   ties  ratio
# 0 -0.067644 -0.067617  False    1.0
# 1 -0.034981 -0.034957  False    1.0
# 2 -0.012095 -0.012074  False    1.0
# 3 -0.000835 -0.000825  False    1.0
# 4  0.001931  0.001937  False    1.0

# %% [markdown]
# #### Simulation overview results

# %%
def heatmap_heuristics_homogeneous(
    outcome: str = "accuracy_opinion",
    heuristic_size_list: list = [5, 7, 9],
    show: bool = True,
):

    df_total = pd.DataFrame()

    for heuristic_size in heuristic_size_list:
        df = produce_df_1samp(
            outcome=outcome, 
            heuristic_size=heuristic_size, 
            n_sources_list=[13, 15, 17],
            compute_ci=False)
        df["heuristic_size"] = heuristic_size
        df["effect_percent"] = 100 * df["difference"]
        
        df_total = pd.concat([df_total, df])
    
    heatmap_df = df_total.pivot(
        index="rel_mean",
        columns=["heuristic_size", "n_sources"],
        values="effect_percent",
    )
    heatmap_df.sort_index(inplace=True, ascending=False)

    sns.set_style("white")
    font_style = {"family": "Times New Roman", "size": 12}
    plt.rc("font", **font_style)
    plt.figure(figsize=(8, 3))

    heatmap_params = {
        "annot": True,
        "cmap": "coolwarm",
        "square": True,
        "cbar_kws": {"shrink": 0.4},
        "vmin": -10,
        "vmax": 10,
        "fmt": '',
    }
    
    annot_df = heatmap_df.copy().map(lambda x: f"{x:.1f}") # .map(lambda x: f"{x:.1f}")
    effect_df = df_total.pivot(index="rel_mean", columns=["heuristic_size", "n_sources"], values="effect_size")
    effect_low = (effect_df < 0.1)
    effect_mid = (effect_df >= 0.1) & (effect_df < 0.3)
    annot_df[effect_low] = annot_df[effect_low] + "'"
    annot_df[effect_mid] = annot_df[effect_mid] + "''"
    
    pvalue_df = df_total.pivot(index="rel_mean", columns=["heuristic_size", "n_sources"], values="p_value")
    not_sig = (pvalue_df > 0.001)
    annot_df[not_sig] = ""
    
    heatmap_params["annot"] = annot_df
    
    fig = sns.heatmap(
        heatmap_df,
        **heatmap_params,
    )

    fig.set_xlabel("Heuristic size (#) - Sources (#)")
    fig.set_ylabel("Reliability (mean)")
    plt.yticks(rotation=0)
    plt.savefig(
        f"figures/images/robustness/heatmap_heuristics_homogeneous_{outcome}.eps",
        bbox_inches="tight",
        dpi=800,
        format="eps",
    )
    plt.savefig(
        f"figures/images/robustness/heatmap_heuristics_homogeneous_{outcome}.png",
        bbox_inches="tight",
        dpi=800,
    )
    if show:
        plt.show()
    plt.close()

# %%
for outcome in ["accuracy_opinion", "accuracy_evidence", "accuracy_bounded"]:
    print("="*40)
    print(f"{translate_outcome_mechanism[outcome].capitalize()}")
    print("="*40)
    heatmap_heuristics_homogeneous(outcome=outcome, show=True)
# Out:
# ========================================
# Opinion-based mechanism
# ========================================
# ========================================
# Evidence-based mechanism
# ========================================
# ========================================
# Boundedly-rational evidence-based mechanism
# ========================================

# %% [markdown]
# #### Individual scores for different heuristic sizes

# %%
data_total = np.empty((0, 3))
scores_df = pd.DataFrame()
for heuristic_size in [int(5), int(7), int(9)]:
    for rel_mean in [0.55, 0.60, 0.65, 0.70, 0.75]:
        n_sources = 13
        reliability_distribution = ("equi", rel_mean, 0.2)
        sources = Sources(n_sources, reliability_distribution)
        n_possible_heuristics = comb(n_sources, heuristic_size)
        team = generate_expert_team(sources, heuristic_size, n_possible_heuristics)
        data = np.array([[agent.score, rel_mean, heuristic_size] for agent in team.members])
        data_total = np.append(data_total, data, axis=0)
        # data_df = pd.DataFrame(data, columns=["score", "rel_mean", "heuristic_size"])
        # scores_df = pd.concat([scores_df, data_df], axis=1)
scores_df = pd.DataFrame(data_total, columns=["score", "rel_mean", "heuristic_size"])

# %%
sns.set_style("whitegrid")
font_style = {"family": "Times New Roman", "size": 12}
plt.rc("font", **font_style)
plt.figure(figsize=(10, 4))

fig = sns.boxplot(data=scores_df, x="rel_mean", y="score", hue="heuristic_size", palette="coolwarm")
fig.set_yticks(0.4 + 0.1 * np.arange(7, dtype=int))
# fig.set_title("Individual scores")
fig.set_xlabel("Mean source reliability")
fig.set_ylabel("Score")

fig.legend(title="Heuristic size (#)", loc="upper left")
fig.legend_.texts[0].set_text(int(5))
fig.legend_.texts[1].set_text(int(7))
fig.legend_.texts[2].set_text(int(9))
plt.savefig(
    f"figures/individual_scores_various_heuristics.png",
    bbox_inches="tight",
    dpi=800,
)

# %% [markdown]
# ### Heterogeneous case

# %% [markdown]
# We consider heterogeneous pools of agents with heuristic size in `[5, 7, 9]` and in settings with 13 and 15 sources.
#
# The number of sources is chosen in such a way that the total number of possible heuristics is roughly between 1,200 and 15,000.

# %%
data =[]
for n_sources in [11, 13, 15, 17]:
    n_possible_heuristics = comb(n_sources, 5) + comb(n_sources, 7) + comb(n_sources, 9)
    data.append((n_sources, n_possible_heuristics))
    df = pd.DataFrame(data, columns=["n_sources", "n_possible_heuristics"])
    df["n_possible_heuristics"] = df["n_possible_heuristics"].map('{:,}'.format)
display(df)
# Out:
#    n_sources n_possible_heuristics
# 0         11                   847
# 1         13                 3,718
# 2         15                14,443
# 3         17                49,946

# %% [markdown]
# #### Simulations

# %%
rels = [
    ("equi", rel_mean, 0.2)
    for rel_mean in [0.55, 0.60, 0.65, 0.7, 0.75]]

GridSimulation(
    team_types=["expert", "diverse"],
    n_sources_list=[13, 15],
    reliability_distribution_list=rels,
    heuristic_size=[5, 7, 9],
    n_samples=10**3,
).run()
# Out:
#           team_types  n_sources reliability_distribution heuristic_size  \
# 0  [expert, diverse]         13        (equi, 0.55, 0.2)      [5, 7, 9]
# 1  [expert, diverse]         13         (equi, 0.6, 0.2)      [5, 7, 9]
# 2  [expert, diverse]         13        (equi, 0.65, 0.2)      [5, 7, 9]
# 3  [expert, diverse]         13         (equi, 0.7, 0.2)      [5, 7, 9]
# 4  [expert, diverse]         13        (equi, 0.75, 0.2)      [5, 7, 9]
#
#    team_size  n_samples estimate_sample_size
# 0          9       1000                 None
# 1          9       1000                 None
# 2          9       1000                 None
# 3          9       1000                 None
# 4          9       1000                 None
# Running simulation 0 out of 5...
# Calculating/estimating accuracy and bounded pool accuracy:   0%|          | 0/1001 [00:00<?, ?it/s]
# Calculating pool accuracy:   0%|          | 0/2 [00:00<?, ?it/s]
# Running simulation 1 out of 5...
# Calculating/estimating accuracy and bounded pool accuracy:   0%|          | 0/1001 [00:00<?, ?it/s]
# Calculating pool accuracy:   0%|          | 0/2 [00:00<?, ?it/s]
# Running simulation 2 out of 5...
# Calculating/estimating accuracy and bounded pool accuracy:   0%|          | 0/1001 [00:00<?, ?it/s]
# Calculating pool accuracy:   0%|          | 0/2 [00:00<?, ?it/s]
# Running simulation 3 out of 5...
# Calculating/estimating accuracy and bounded pool accuracy:   0%|          | 0/1001 [00:00<?, ?it/s]
# Calculating pool accuracy:   0%|          | 0/2 [00:00<?, ?it/s]
# Running simulation 4 out of 5...
# Calculating/estimating accuracy and bounded pool accuracy:   0%|          | 0/1001 [00:00<?, ?it/s]
# Calculating pool accuracy:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# #### Simulation statistics tables

# %%
for outcome in ["accuracy_opinion", "accuracy_evidence", "accuracy_bounded"]:
    print("="*40)
    print(f"{translate_outcome_mechanism[outcome].capitalize()}")
    print("="*40)
    display(produce_df_1samp(
        outcome=outcome, 
        heuristic_size=[5, 7, 9], 
        n_sources_list=[13, 15],
        ).sort_values(by="n_sources")
    )
# Out:
# ========================================
# Opinion-based mechanism
# ========================================
#    n_sources  rel_mean  difference  error_reduction  p_value  effect_size  \
# 5         13      0.55      -0.080            -28.2      0.0        0.866
# 6         13      0.60      -0.048            -25.2      0.0        0.866
# 7         13      0.65      -0.029            -25.7      0.0        0.866
# 8         13      0.70      -0.016            -28.7      0.0        0.866
# 9         13      0.75      -0.008            -35.6      0.0        0.866
# 0         15      0.55      -0.083            -30.6      0.0        0.866
# 1         15      0.60      -0.049            -28.0      0.0        0.866
# 2         15      0.65      -0.027            -27.1      0.0        0.866
# 3         15      0.70      -0.013            -26.5      0.0        0.866
# 4         15      0.75      -0.005            -26.0      0.0        0.866
#
#      ci_low   ci_high   ties  ratio
# 5 -0.080225 -0.079051  False    1.0
# 6 -0.048649 -0.047515  False    1.0
# 7 -0.029266 -0.028382  False    1.0
# 8 -0.016245 -0.015540  False    1.0
# 9 -0.008034 -0.007639  False    1.0
# 0 -0.083229 -0.082571  False    1.0
# 1 -0.049619 -0.048957  False    1.0
# 2 -0.027157 -0.026431  False    1.0
# 3 -0.012777 -0.012261  False    1.0
# 4 -0.004802 -0.004569  False    1.0
# ========================================
# Evidence-based mechanism
# ========================================
#    n_sources  rel_mean  difference  error_reduction  p_value  effect_size  \
# 5         13      0.55      -0.054            -17.7      NaN          NaN
# 6         13      0.60      -0.017             -8.3      NaN          NaN
# 7         13      0.65       0.006              4.7      NaN          NaN
# 8         13      0.70       0.000              0.0      NaN          NaN
# 9         13      0.75       0.000              0.0      NaN          NaN
# 0         15      0.55      -0.049            -16.5      NaN          NaN
# 1         15      0.60      -0.011             -5.5      NaN          NaN
# 2         15      0.65      -0.006             -5.4      NaN          NaN
# 3         15      0.70      -0.001             -1.7      NaN          NaN
# 4         15      0.75       0.001              3.4      NaN          NaN
#
#    ci_low  ci_high   ties  ratio
# 5     NaN      NaN  False    NaN
# 6     NaN      NaN  False    NaN
# 7     NaN      NaN  False    NaN
# 8     NaN      NaN  False    NaN
# 9     NaN      NaN  False    NaN
# 0     NaN      NaN  False    NaN
# 1     NaN      NaN  False    NaN
# 2     NaN      NaN  False    NaN
# 3     NaN      NaN  False    NaN
# 4     NaN      NaN  False    NaN
# ========================================
# Boundedly-rational evidence-based mechanism
# ========================================
#    n_sources  rel_mean  difference  error_reduction  p_value  effect_size  \
# 5         13      0.55      -0.072            -25.5      0.0        0.866
# 6         13      0.60      -0.037            -19.1      0.0        0.866
# 7         13      0.65      -0.016            -14.4      0.0        0.866
# 8         13      0.70      -0.006            -10.2      0.0        0.866
# 9         13      0.75      -0.001             -5.5      0.0        0.866
# 0         15      0.55      -0.074            -27.5      0.0        0.866
# 1         15      0.60      -0.035            -20.0      0.0        0.866
# 2         15      0.65      -0.012            -12.1      0.0        0.866
# 3         15      0.70      -0.001             -1.6      0.0        0.861
# 4         15      0.75       0.002             12.1      0.0        0.866
#
#      ci_low   ci_high   ties  ratio
# 5 -0.072244 -0.072171  False  1.000
# 6 -0.036736 -0.036428  False  1.000
# 7 -0.016301 -0.015994  False  1.000
# 8 -0.005772 -0.005569  False  1.000
# 9 -0.001286 -0.001167  False  0.999
# 0 -0.074401 -0.074401  False  1.000
# 1 -0.035266 -0.035266  False  1.000
# 2 -0.012008 -0.012008  False  1.000
# 3 -0.000773 -0.000773  False  0.992
# 4  0.001963  0.001963  False  0.990

# %% [markdown]
# #### Simulation overview results

# %%
for outcome in ["accuracy_opinion", "accuracy_evidence", "accuracy_bounded"]:
    print("="*40)
    print(f"{translate_outcome_mechanism[outcome].capitalize()}")
    print("="*40)
    heatmap(
        outcome=outcome, 
        heuristic_size=[5, 7, 9], 
        n_sources_list=[13, 15],
        colors=True, 
        show=True, 
        filename=f"figures/images/robustness/heatmap_heuristics_heterogeneous_{outcome}",
    )
# Out:
# ========================================
# Opinion-based mechanism
# ========================================
# ========================================
# Evidence-based mechanism
# ========================================
# ========================================
# Boundedly-rational evidence-based mechanism
# ========================================

# %% [markdown]
# ## Number of sources
# ---

# %% [markdown]
# We vary the number of sources to not only include `13` and `17` but also `21`.
#
# As a sidenote: increasing the number of sources, leads to a significant increase in the number of possible heuristics.

# %%
n_sources_list = [13, 17, 21]
heuristic_size = 5
data = []

for n_sources in n_sources_list:
    n_possible_heuristics = comb(n_sources, heuristic_size)
    data.append((n_sources, n_possible_heuristics))
df = pd.DataFrame(data, columns=["n_sources", "n_possible_heuristics"])
df["n_possible_heuristics"] = df["n_possible_heuristics"].map('{:,}'.format)
display(df)
# Out:
#    n_sources n_possible_heuristics
# 0         13                 1,287
# 1         17                 6,188
# 2         21                20,349

# %% [markdown]
# ### Simulations

# %%
rels = [
    ("equi", rel_mean, 0.2)
    for rel_mean in [0.55, 0.60, 0.65, 0.7, 0.75]]

GridSimulation(
    team_types=["expert", "diverse"],
    n_sources_list=[21],
    reliability_distribution_list=rels,
    heuristic_size=5,
    n_samples=10**3,
    estimate_sample_size=10**5,
).run()
# Out:
#           team_types  n_sources reliability_distribution  heuristic_size  \
# 0  [expert, diverse]         21        (equi, 0.55, 0.2)               5
# 1  [expert, diverse]         21         (equi, 0.6, 0.2)               5
# 2  [expert, diverse]         21        (equi, 0.65, 0.2)               5
# 3  [expert, diverse]         21         (equi, 0.7, 0.2)               5
# 4  [expert, diverse]         21        (equi, 0.75, 0.2)               5
#
#    team_size  n_samples  estimate_sample_size
# 0          9        100                  1000
# 1          9        100                  1000
# 2          9        100                  1000
# 3          9        100                  1000
# 4          9        100                  1000
# Running simulation 0
# Calculating accuracies and bounded pool accuracies: 100%|██████████| 101/101 [00:00<?, ?it/s]
# Calculating pool accuracies: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Running simulation 1
# Calculating accuracies and bounded pool accuracies: 100%|██████████| 101/101 [00:00<00:00, 49861.66it/s]
# Calculating pool accuracies: 100%|██████████| 2/2 [00:00<00:00, 2003.97it/s]
# Running simulation 2
# Calculating accuracies and bounded pool accuracies: 100%|██████████| 101/101 [00:00<?, ?it/s]
# Calculating pool accuracies: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Running simulation 3
# Calculating accuracies and bounded pool accuracies: 100%|██████████| 101/101 [00:00<?, ?it/s]
# Calculating pool accuracies: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Running simulation 4
# Calculating accuracies and bounded pool accuracies: 100%|██████████| 101/101 [00:00<?, ?it/s]
# Calculating pool accuracies: 100%|██████████| 2/2 [00:00<?, ?it/s]

# %% [markdown]
# ### Simulation statistics table

# %%
for outcome in ["accuracy_opinion", "accuracy_evidence", "accuracy_bounded"]:
    print("="*40)
    print(f"{translate_outcome_mechanism[outcome].capitalize()}")
    print("="*40)
    display(produce_df_1samp(
        outcome=outcome, 
        compute_ci=False,
        n_sources_list= [13, 17, 21],
        )
    )
# Out:
# ========================================
# Opinion-based mechanism
# ========================================
#     n_sources  rel_mean  difference  error_reduction  p_value  effect_size  \
# 0          13      0.55      -0.081            -28.6   0.0000        0.866
# 1          13      0.60      -0.043            -21.9   0.0000        0.866
# 2          13      0.65      -0.015            -12.1   0.0000        0.866
# 3          13      0.70       0.000              0.1   0.1626        0.014
# 4          13      0.75       0.005             15.3   0.0000        0.863
# 5          17      0.55      -0.083            -31.6   0.0000        0.866
# 6          17      0.60      -0.033            -18.2   0.0000        0.866
# 7          17      0.65      -0.000             -0.3   0.0000        0.087
# 8          17      0.70       0.013             24.9   0.0000        0.866
# 9          17      0.75       0.012             66.8   0.0000        0.866
# 10         21      0.55      -0.080            -31.7   0.0000        0.866
# 11         21      0.60      -0.020            -11.7   0.0000        0.866
# 12         21      0.65       0.013             14.0   0.0000        0.866
# 13         21      0.70       0.022             59.3   0.0000        0.866
# 14         21      0.75       0.016            148.9   0.0000        0.866
#
#     ci_low  ci_high   ties   ratio
# 0      NaN      NaN  False  1.0000
# 1      NaN      NaN  False  1.0000
# 2      NaN      NaN  False  0.9998
# 3      NaN      NaN  False  0.5064
# 4      NaN      NaN  False  0.9792
# 5      NaN      NaN  False  1.0000
# 6      NaN      NaN  False  1.0000
# 7      NaN      NaN  False  0.5278
# 8      NaN      NaN  False  1.0000
# 9      NaN      NaN  False  1.0000
# 10     NaN      NaN  False  1.0000
# 11     NaN      NaN  False  1.0000
# 12     NaN      NaN  False  1.0000
# 13     NaN      NaN  False  1.0000
# 14     NaN      NaN  False  1.0000
# ========================================
# Evidence-based mechanism
# ========================================
#     n_sources  rel_mean  difference  error_reduction  p_value  effect_size  \
# 0          13      0.55      -0.054            -17.7      NaN          NaN
# 1          13      0.60      -0.027            -13.4      NaN          NaN
# 2          13      0.65      -0.008             -6.6      NaN          NaN
# 3          13      0.70       0.002              2.7      NaN          NaN
# 4          13      0.75       0.004             15.8      NaN          NaN
# 5          17      0.55      -0.070            -26.4      NaN          NaN
# 6          17      0.60      -0.026            -15.1      NaN          NaN
# 7          17      0.65       0.001              0.8      NaN          NaN
# 8          17      0.70       0.010             24.7      NaN          NaN
# 9          17      0.75       0.008             66.0      NaN          NaN
# 10         21      0.55      -0.074            -30.1      NaN          NaN
# 11         21      0.60      -0.018            -11.3      NaN          NaN
# 12         21      0.65       0.011             14.9      NaN          NaN
# 13         21      0.70       0.016             63.2      NaN          NaN
# 14         21      0.75       0.010            162.2      NaN          NaN
#
#     ci_low  ci_high   ties  ratio
# 0      NaN      NaN  False    NaN
# 1      NaN      NaN  False    NaN
# 2      NaN      NaN  False    NaN
# 3      NaN      NaN  False    NaN
# 4      NaN      NaN  False    NaN
# 5      NaN      NaN  False    NaN
# 6      NaN      NaN  False    NaN
# 7      NaN      NaN  False    NaN
# 8      NaN      NaN  False    NaN
# 9      NaN      NaN  False    NaN
# 10     NaN      NaN  False    NaN
# 11     NaN      NaN  False    NaN
# 12     NaN      NaN  False    NaN
# 13     NaN      NaN  False    NaN
# 14     NaN      NaN  False    NaN
# ========================================
# Boundedly-rational evidence-based mechanism
# ========================================
#     n_sources  rel_mean  difference  error_reduction  p_value  effect_size  \
# 0          13      0.55      -0.074            -26.4      0.0        0.866
# 1          13      0.60      -0.031            -15.9      0.0        0.866
# 2          13      0.65      -0.002             -1.8      0.0        0.774
# 3          13      0.70       0.011             17.6      0.0        0.866
# 4          13      0.75       0.012             48.7      0.0        0.866
# 5          17      0.55      -0.075            -28.3      0.0        0.866
# 6          17      0.60      -0.019            -10.6      0.0        0.866
# 7          17      0.65       0.013             13.2      0.0        0.866
# 8          17      0.70       0.023             54.6      0.0        0.866
# 9          17      0.75       0.017            133.2      0.0        0.866
# 10         21      0.55      -0.068            -26.7      0.0        0.866
# 11         21      0.60      -0.002             -1.1      0.0        0.354
# 12         21      0.65       0.030             38.2      0.0        0.866
# 13         21      0.70       0.033            120.5      0.0        0.866
# 14         21      0.75       0.021            321.1      0.0        0.866
#
#     ci_low  ci_high   ties   ratio
# 0      NaN      NaN  False  1.0000
# 1      NaN      NaN  False  1.0000
# 2      NaN      NaN  False  0.8677
# 3      NaN      NaN  False  1.0000
# 4      NaN      NaN  False  1.0000
# 5      NaN      NaN  False  1.0000
# 6      NaN      NaN  False  1.0000
# 7      NaN      NaN  False  0.9992
# 8      NaN      NaN  False  1.0000
# 9      NaN      NaN  False  1.0000
# 10     NaN      NaN  False  1.0000
# 11     NaN      NaN  False  0.6400
# 12     NaN      NaN  False  1.0000
# 13     NaN      NaN  False  1.0000
# 14     NaN      NaN  False  1.0000

# %% [markdown]
# ### Simulation overview results

# %%
for outcome in ["accuracy_opinion", "accuracy_evidence", "accuracy_bounded"]:
    print("="*40)
    print(f"{translate_outcome_mechanism[outcome].capitalize()}")
    print("="*40)
    show_cbar = True if outcome == "accuracy_bounded" else False
    heatmap(
        outcome=outcome, 
        n_sources_list=[13, 17, 21], 
        show=True, 
        show_cbar=show_cbar, 
        filename=f"figures/images/robustness/heatmap_nsources_{outcome}",
        colors=True,
    )
# Out:
# ========================================
# Opinion-based mechanism
# ========================================
# ========================================
# Evidence-based mechanism
# ========================================
# ========================================
# Boundedly-rational evidence-based mechanism
# ========================================

# %% [markdown]
# ## Reliability distributions
# ---

# %% [markdown]
# We are varying the range in the equidistant reliability distributions to include not only `0.2` but also `0.15` and `0.25`.
#
# For example, when the reliabiltiy mean is `0.6`, the source reliabilities originally ranged from `0.5` to `0.7`, but in the new settings they range from `0.525` to `0.675` and from `0.475` to `0.725` respectively.

# %% [markdown]
# ### Simulations

# %%
rels = [
    ("equi", rel_mean, 0.15)
    for rel_mean in [0.55, 0.60, 0.65, 0.7, 0.75]]

GridSimulation(
    team_types=["expert", "diverse"],
    n_sources_list=[13, 17],
    reliability_distribution_list=rels,
    n_samples=10**3,
    estimate_sample_size=10**3,
).run()
# Out:
#           team_types  n_sources reliability_distribution  heuristic_size  \
# 0  [expert, diverse]         17       (equi, 0.55, 0.15)               5
# 1  [expert, diverse]         17        (equi, 0.6, 0.15)               5
# 2  [expert, diverse]         17       (equi, 0.65, 0.15)               5
# 3  [expert, diverse]         17        (equi, 0.7, 0.15)               5
# 4  [expert, diverse]         17       (equi, 0.75, 0.15)               5
#
#    team_size  n_samples estimate_sample_size
# 0          9       1000                 None
# 1          9       1000                 None
# 2          9       1000                 None
# 3          9       1000                 None
# 4          9       1000                 None
# Running simulation 0 out of 5...
# Calculating/estimating accuracies and bounded pool accuracies:   0%|          | 0/1001 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[2], line 11
#
#       1 rels = [
#
#       2     ("equi", rel_mean, 0.15)
#
#       3     for rel_mean in [0.55, 0.60, 0.65, 0.7, 0.75]]
#
#       5 GridSimulation(
#
#       6     team_types=["expert", "diverse"],
#
#       7     n_sources_list=[17],
#
#       8     reliability_distribution_list=rels,
#
#       9     n_samples=10**3,
#
#      10     estimate_sample_size=10**3,
#
# ---> 11 ).run()
#
#
#
# File c:\Users\heind\OneDrive - Universiteit Utrecht\GitHub\DiversityAbility\grid_simulation.py:34, in GridSimulation.run(self)
#
#      32 params_dict = params.where(pd.notnull(params), None).to_dict()
#
#      33 print(f"Running simulation {idx} out of {total}...")
#
# ---> 34 Simulation(**params_dict).run()
#
#
#
# File c:\Users\heind\OneDrive - Universiteit Utrecht\GitHub\DiversityAbility\simulation.py:53, in Simulation.run(self)
#
#      51 with Pool() as pool:
#
#      52     params, total = self.get_params()
#
# ---> 53     results_df = pd.DataFrame(
#
#      54         tqdm(
#
#      55             pool.map(self.team_simulate, params),
#
#      56             total=total,
#
#      57             desc="Calculating/estimating accuracies and bounded pool accuracies",
#
#      58         )
#
#      59     )
#
#      61 # Run simulations in parallel for pool accuracies
#
#      62 with Pool() as pool:
#
#
#
# File c:\Users\heind\.conda\envs\work\Lib\site-packages\pandas\core\frame.py:847, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#
#     845         data = np.asarray(data)
#
#     846     else:
#
# --> 847         data = list(data)
#
#     848 if len(data) > 0:
#
#     849     if is_dataclass(data[0]):
#
#
#
# File c:\Users\heind\.conda\envs\work\Lib\site-packages\tqdm\notebook.py:250, in tqdm_notebook.__iter__(self)
#
#     248 try:
#
#     249     it = super(tqdm_notebook, self).__iter__()
#
# --> 250     for obj in it:
#
#     251         # return super(tqdm...) will not catch exception
#
#     252         yield obj
#
#     253 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#
#
#
# File c:\Users\heind\.conda\envs\work\Lib\site-packages\tqdm\std.py:1181, in tqdm.__iter__(self)
#
#    1178 time = self._time
#
#    1180 try:
#
# -> 1181     for obj in iterable:
#
#    1182         yield obj
#
#    1183         # Update and possibly print the progressbar.
#
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
#
#
# File c:\Users\heind\.conda\envs\work\Lib\concurrent\futures\process.py:608, in _chain_from_iterable_of_lists(iterable)
#
#     602 def _chain_from_iterable_of_lists(iterable):
#
#     603     """
#
#     604     Specialized implementation of itertools.chain.from_iterable.
#
#     605     Each item in *iterable* should be a list.  This function is
#
#     606     careful not to keep references to yielded objects.
#
#     607     """
#
# --> 608     for element in iterable:
#
#     609         element.reverse()
#
#     610         while element:
#
#
#
# File c:\Users\heind\.conda\envs\work\Lib\concurrent\futures\_base.py:619, in Executor.map.<locals>.result_iterator()
#
#     616 while fs:
#
#     617     # Careful not to keep a reference to the popped future
#
#     618     if timeout is None:
#
# --> 619         yield _result_or_cancel(fs.pop())
#
#     620     else:
#
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
#
#
# File c:\Users\heind\.conda\envs\work\Lib\concurrent\futures\_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#
#     315 try:
#
#     316     try:
#
# --> 317         return fut.result(timeout)
#
#     318     finally:
#
#     319         fut.cancel()
#
#
#
# File c:\Users\heind\.conda\envs\work\Lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#
#     448 elif self._state == FINISHED:
#
#     449     return self.__get_result()
#
# --> 451 self._condition.wait(timeout)
#
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
#     454     raise CancelledError()
#
#
#
# File c:\Users\heind\.conda\envs\work\Lib\threading.py:334, in Condition.wait(self, timeout)
#
#     332 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#
#     333     if timeout is None:
#
# --> 334         waiter.acquire()
#
#     335         gotit = True
#
#     336     else:
#
#
#
# KeyboardInterrupt:

# %%
rels = [
    ("equi", rel_mean, 0.25)
    for rel_mean in [0.55, 0.60, 0.65, 0.7, 0.75]]

GridSimulation(
    team_types=["expert", "diverse"],
    n_sources_list=[13, 17],
    reliability_distribution_list=rels,
    n_samples=10**3,
    estimate_sample_size=10**3,
).run()
# Out:
#           team_types  n_sources reliability_distribution  heuristic_size  \
# 0  [expert, diverse]         13       (equi, 0.55, 0.25)               5
# 1  [expert, diverse]         13        (equi, 0.6, 0.25)               5
# 2  [expert, diverse]         13       (equi, 0.65, 0.25)               5
# 3  [expert, diverse]         13        (equi, 0.7, 0.25)               5
# 4  [expert, diverse]         13       (equi, 0.75, 0.25)               5
#
#    team_size  n_samples estimate_sample_size
# 0          9       1000                 None
# 1          9       1000                 None
# 2          9       1000                 None
# 3          9       1000                 None
# 4          9       1000                 None
# Running simulation 0
# team_types                   [expert, diverse]
# n_sources                                   13
# reliability_distribution    (equi, 0.55, 0.25)
# heuristic_size                               5
# team_size                                    9
# n_samples                                 1000
# estimate_sample_size                      None
# Name: 0, dtype: object
# 100%|██████████| 1001/1001 [05:22<00:00,  3.11it/s]
# Running simulation 1
# team_types                  [expert, diverse]
# n_sources                                  13
# reliability_distribution    (equi, 0.6, 0.25)
# heuristic_size                              5
# team_size                                   9
# n_samples                                1000
# estimate_sample_size                     None
# Name: 1, dtype: object
# 100%|██████████| 1001/1001 [05:01<00:00,  3.32it/s]
# Running simulation 2
# team_types                   [expert, diverse]
# n_sources                                   13
# reliability_distribution    (equi, 0.65, 0.25)
# heuristic_size                               5
# team_size                                    9
# n_samples                                 1000
# estimate_sample_size                      None
# Name: 2, dtype: object
# 100%|██████████| 1001/1001 [04:58<00:00,  3.35it/s]
# Running simulation 3
# team_types                  [expert, diverse]
# n_sources                                  13
# reliability_distribution    (equi, 0.7, 0.25)
# heuristic_size                              5
# team_size                                   9
# n_samples                                1000
# estimate_sample_size                     None
# Name: 3, dtype: object
# 100%|██████████| 1001/1001 [04:54<00:00,  3.39it/s]
# Running simulation 4
# team_types                   [expert, diverse]
# n_sources                                   13
# reliability_distribution    (equi, 0.75, 0.25)
# heuristic_size                               5
# team_size                                    9
# n_samples                                 1000
# estimate_sample_size                      None
# Name: 4, dtype: object
# 100%|██████████| 1001/1001 [04:53<00:00,  3.41it/s]

# %% [markdown]
# ### Simulation statistics tables

# %%
for outcome in ["accuracy_opinion", "accuracy_evidence", "accuracy_bounded"]:
    print("="*80)
    print(f"{translate_outcome_mechanism[outcome].capitalize()}")
    print("="*80)
    for rel_range in [0.15, 0.25]:
        df_dummy = produce_df_1samp(outcome=outcome, reliability_range=rel_range)
        print(f"--- Reliability range: {rel_range}")
        display(df_dummy)
# Out:
# ================================================================================
# Opinion-based mechanism
# ================================================================================
# --- Reliability range: 0.15
#    n_sources  rel_mean  difference  error_reduction  p_value  effect_size  \
# 0         13      0.55      -0.053            -17.2      0.0        0.866
# 1         13      0.60      -0.019             -8.7      0.0        0.866
# 2         13      0.65       0.004              3.0      0.0        0.741
# 3         13      0.70       0.014             19.8      0.0        0.866
# 4         13      0.75       0.014             45.5      0.0        0.866
# 5         17      0.55      -0.052            -17.7      0.0        0.866
# 6         17      0.60      -0.006             -3.1      0.0        0.797
# 7         17      0.65       0.021             18.0      0.0        0.866
# 8         17      0.70       0.028             53.9      0.0        0.866
# 9         17      0.75       0.022            120.5      0.0        0.866
#
#      ci_low   ci_high   ties  ratio
# 0 -0.053689 -0.052945  False  1.000
# 1 -0.019777 -0.018838  False  1.000
# 2  0.003820  0.004536  False  0.845
# 3  0.014197  0.014621  False  1.000
# 4  0.013937  0.014242  False  1.000
# 5 -0.052807 -0.051682  False  1.000
# 6 -0.006949 -0.005975  False  0.883
# 7  0.020473  0.021095  False  1.000
# 8  0.027983  0.028332  False  1.000
# 9  0.022142  0.022292  False  1.000
# --- Reliability range: 0.25
#    n_sources  rel_mean  difference  error_reduction  p_value  effect_size  \
# 0         13      0.55      -0.107            -42.0      0.0        0.866
# 1         13      0.60      -0.065            -37.5      0.0        0.866
# 2         13      0.65      -0.032            -30.2      0.0        0.866
# 3         13      0.70      -0.013            -21.5      0.0        0.866
# 4         13      0.75      -0.003            -12.6      0.0        0.828
# 5         17      0.55      -0.113            -48.3      0.0        0.866
# 6         17      0.60      -0.058            -37.1      0.0        0.866
# 7         17      0.65      -0.020            -21.3      0.0        0.866
# 8         17      0.70      -0.001             -1.3      0.0        0.198
# 9         17      0.75       0.004             21.9      0.0        0.864
#
#      ci_low   ci_high   ties  ratio
# 0 -0.107958 -0.106570  False  1.000
# 1 -0.065754 -0.064701  False  1.000
# 2 -0.033244 -0.031972  False  1.000
# 3 -0.013021 -0.012279  False  0.999
# 4 -0.003502 -0.003070  False  0.909
# 5 -0.113735 -0.112307  False  1.000
# 6 -0.058671 -0.057393  False  1.000
# 7 -0.020640 -0.019547  False  1.000
# 8 -0.000933 -0.000370  False  0.580
# 9  0.003683  0.004028  False  0.979
# ================================================================================
# Evidence-based mechanism
# ================================================================================
# --- Reliability range: 0.15
#    n_sources  rel_mean  difference  error_reduction  p_value  effect_size  \
# 0         13      0.55      -0.035            -11.0      NaN          NaN
# 1         13      0.60      -0.012             -5.4      NaN          NaN
# 2         13      0.65       0.003              2.7      NaN          NaN
# 3         13      0.70       0.009             15.0      NaN          NaN
# 4         13      0.75       0.008             33.8      NaN          NaN
# 5         17      0.55      -0.044            -14.9      NaN          NaN
# 6         17      0.60      -0.005             -2.4      NaN          NaN
# 7         17      0.65       0.016             16.5      NaN          NaN
# 8         17      0.70       0.020             49.6      NaN          NaN
# 9         17      0.75       0.013            109.7      NaN          NaN
#
#    ci_low  ci_high   ties  ratio
# 0     NaN      NaN  False    NaN
# 1     NaN      NaN  False    NaN
# 2     NaN      NaN  False    NaN
# 3     NaN      NaN  False    NaN
# 4     NaN      NaN  False    NaN
# 5     NaN      NaN  False    NaN
# 6     NaN      NaN  False    NaN
# 7     NaN      NaN  False    NaN
# 8     NaN      NaN  False    NaN
# 9     NaN      NaN  False    NaN
# --- Reliability range: 0.25
#    n_sources  rel_mean  difference  error_reduction  p_value  effect_size  \
# 0         13      0.55      -0.072            -25.3      NaN          NaN
# 1         13      0.60      -0.041            -22.4      NaN          NaN
# 2         13      0.65      -0.018            -17.1      NaN          NaN
# 3         13      0.70      -0.005             -9.6      NaN          NaN
# 4         13      0.75      -0.000             -0.6      NaN          NaN
# 5         17      0.55      -0.095            -39.7      NaN          NaN
# 6         17      0.60      -0.046            -30.3      NaN          NaN
# 7         17      0.65      -0.013            -15.7      NaN          NaN
# 8         17      0.70       0.001              2.8      NaN          NaN
# 9         17      0.75       0.003             29.2      NaN          NaN
#
#    ci_low  ci_high   ties  ratio
# 0     NaN      NaN  False    NaN
# 1     NaN      NaN  False    NaN
# 2     NaN      NaN  False    NaN
# 3     NaN      NaN  False    NaN
# 4     NaN      NaN  False    NaN
# 5     NaN      NaN  False    NaN
# 6     NaN      NaN  False    NaN
# 7     NaN      NaN  False    NaN
# 8     NaN      NaN  False    NaN
# 9     NaN      NaN  False    NaN
# ================================================================================
# Boundedly-rational evidence-based mechanism
# ================================================================================
# --- Reliability range: 0.15
#    n_sources  rel_mean  difference  error_reduction  p_value  effect_size  \
# 0         13      0.55      -0.047            -15.1      0.0        0.866
# 1         13      0.60      -0.008             -3.5      0.0        0.866
# 2         13      0.65       0.017             13.2      0.0        0.866
# 3         13      0.70       0.025             40.3      0.0        0.866
# 4         13      0.75       0.021             86.8      0.0        0.866
# 5         17      0.55      -0.044            -14.7      0.0        0.866
# 6         17      0.60       0.007              3.6      0.0        0.848
# 7         17      0.65       0.035             33.8      0.0        0.866
# 8         17      0.70       0.038             89.9      0.0        0.866
# 9         17      0.75       0.028            206.1      0.0        0.866
#
#      ci_low   ci_high   ties  ratio
# 0 -0.047020 -0.046403  False  1.000
# 1 -0.007918 -0.007397  False  1.000
# 2  0.016921  0.017178  False  1.000
# 3  0.025238  0.025373  False  1.000
# 4  0.021174  0.021281  False  1.000
# 5 -0.044117 -0.043018  False  1.000
# 6  0.006900  0.007829  False  0.943
# 7  0.034539  0.034960  False  1.000
# 8  0.038289  0.038569  False  1.000
# 9  0.027720  0.027838  False  1.000
# --- Reliability range: 0.25
#    n_sources  rel_mean  difference  error_reduction  p_value  effect_size  \
# 0         13      0.55      -0.101            -39.6      0.0        0.866
# 1         13      0.60      -0.054            -30.9      0.0        0.866
# 2         13      0.65      -0.020            -18.3      0.0        0.866
# 3         13      0.70      -0.002             -3.0      0.0        0.748
# 4         13      0.75       0.004             15.2      0.0        0.866
# 5         17      0.55      -0.105            -44.8      0.0        0.866
# 6         17      0.60      -0.044            -28.4      0.0        0.866
# 7         17      0.65      -0.006             -6.3      0.0        0.787
# 8         17      0.70       0.009             22.7      0.0        0.866
# 9         17      0.75       0.009             72.3      0.0        0.866
#
#      ci_low   ci_high   ties  ratio
# 0 -0.101369 -0.100389  False  1.000
# 1 -0.053833 -0.053468  False  1.000
# 2 -0.019987 -0.019549  False  1.000
# 3 -0.001893 -0.001639  False  0.854
# 4  0.003430  0.003604  False  0.998
# 5 -0.105204 -0.103881  False  1.000
# 6 -0.044833 -0.043853  False  1.000
# 7 -0.006593 -0.005614  False  0.883
# 8  0.009099  0.009561  False  0.998
# 9  0.008930  0.009180  False  1.000

# %% [markdown]
# ### Simulation overview results

# %%
def display_results_range(outcome: str = "accuracy_opinion", n_sources: int = 13):
    data = []
    for rel_range in [0.15, 0.2, 0.25]:
        df_dummy = produce_df_1samp(outcome=outcome, reliability_range=rel_range, compute_ci=False)
        for idx, row in df_dummy.iterrows():
            data.append([
                row["n_sources"], 
                row["rel_mean"], 
                rel_range, 
                row["difference"], 
                row["p_value"],
                row["effect_size"],
                ]                
            )
    
    df_results = pd.DataFrame(
        data, 
        columns=["n_sources", "rel_mean", "rel_range", "difference", "p_value", "effect_size"])
    df_results.loc[:, "effect_percent"] = 100 * df_results["difference"]
    df_results = df_results[df_results["n_sources"] == n_sources]
    return df_results

def heatmap_results_range(outcome: str = "accuracy_opinion", n_sources: int = 13, show_cbar: bool = True):
    df_results = display_results_range(outcome=outcome, n_sources=n_sources)
    heatmap_df = df_results.pivot(index="rel_mean", columns="rel_range", values="effect_percent")
    heatmap_df.sort_index(inplace=True, ascending=False)
    
    sns.set_style("white")
    font_style = {"family": "Times New Roman", "size": 12}
    plt.rc("font", **font_style)
    plt.figure(figsize=(5, 3))
        
    heatmap_params = {
        "annot": True,
        "cmap": "coolwarm",
        "square": True,
        "cbar": show_cbar,
        "cbar_kws": {"shrink": 0.4},
        "vmin": -10,
        "vmax": 10,
    }
    
    annot_df = heatmap_df.copy().map(lambda x: f"{x:.1f}")
    effect_df = df_results.pivot(index="rel_mean", columns="rel_range", values="effect_size")
    effect_low = (effect_df < 0.1)
    effect_mid = (effect_df >= 0.1) & (effect_df < 0.3)
    annot_df[effect_low] = annot_df[effect_low] + "'"
    annot_df[effect_mid] = annot_df[effect_mid] + "''"
    
    pvalue_df = df_results.pivot(index="rel_mean", columns="rel_range", values="p_value")
    not_sig = pvalue_df > 0.001
    annot_df[not_sig] = ""
    
    heatmap_params["annot"] = annot_df
    heatmap_params["fmt"] = ""
    
    fig = sns.heatmap(
        heatmap_df,
        **heatmap_params,
    )

    fig.set_xlabel("Reliability range")
    fig.set_ylabel("Reliability (mean)")
    plt.yticks(rotation=0)
    plt.savefig(
        f"figures/images/robustness/heatmap_range_{outcome}_nsources{n_sources}.eps",
        bbox_inches="tight",
        dpi=800,
        format="eps",
    )
    plt.savefig(
        f"figures/images/robustness/heatmap_range_{outcome}_nsources{n_sources}.png",
        bbox_inches="tight",
        dpi=800,
    )
    plt.show()
    plt.close()

# %%
for outcome in ["accuracy_opinion", "accuracy_evidence", "accuracy_bounded"]:
    print("="*40)
    print(f"{translate_outcome_mechanism[outcome].capitalize()}")
    print("="*40)
    for n_sources in [13, 17]:
        print(f"--- Number of sources: {n_sources}")
        show_cbar = True if outcome == "accuracy_bounded" else False
        heatmap_results_range(outcome=outcome, n_sources=n_sources, show_cbar=show_cbar)
# Out:
# ========================================
# Opinion-based mechanism
# ========================================
# --- Number of sources: 13
# --- Number of sources: 17
# ========================================
# Evidence-based mechanism
# ========================================
# --- Number of sources: 13
# --- Number of sources: 17
# ========================================
# Boundedly-rational evidence-based mechanism
# ========================================
# --- Number of sources: 13
# --- Number of sources: 17
